# %%
import sys
sys.path.append('..')
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from plotting_tools import cplot
from active_contours import K
import seaborn as sns
sns.set(color_codes=True)

# %%
L = 100
s = np.linspace(0,L,1000)
gamma = 0.042

# %%
gammas = np.linspace(0.042, 0.2, 5)

# %%
gammas
# Out:
# array([0.042 , 0.0815, 0.121 , 0.1605, 0.2   ])

# %%
for gamma in gammas:
    plt.plot(s, K(s, gamma, L), label=r'$\gamma$: {0:0.3f}'.format(gamma))
plt.plot(s, K(s, 100, L), label=r'$\gamma$: {}'.format(100))
plt.legend()
plt.title(r'Noyau $K_{\gamma}$')
plt.savefig('results/noyau.eps', quality=100)
